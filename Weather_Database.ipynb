# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 714

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=30bb5824683a5bf4e86c4f20db4d3f55

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+") 

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_condition = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_condition,
                          "Country": city_country})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grand gaube
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | princeton
# Processing Record 4 of Set 1 | trairi
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | geraldton
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | nagua
# Processing Record 14 of Set 1 | olinda
# Processing Record 15 of Set 1 | batemans bay
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | tasiilaq
# Processing Record 18 of Set 1 | nuuk
# Processing Record 19 of Set 1 | honiara
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | marrakesh
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | lappeenranta
# Processing Record 25 of Set 1 | norman wells
# Processing Record 26 of Set 1 | constantine
# Processing Record 27 of Set 1 | luderitz
# Processing Record 28 of Set 1 | acari
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | mehamn
# Processing Record 31 of Set 1 | alofi
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | ust-nera
# Processing Record 34 of Set 1 | rodino
# Processing Record 35 of Set 1 | waingapu
# Processing Record 36 of Set 1 | flagstaff
# Processing Record 37 of Set 1 | nhulunbuy
# Processing Record 38 of Set 1 | kerrville
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | pucallpa
# Processing Record 42 of Set 1 | verkhnevilyuysk
# Processing Record 43 of Set 1 | kano
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | zhuhai
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | kautokeino
# Processing Record 1 of Set 2 | yantal
# Processing Record 2 of Set 2 | vrangel
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | burica
# City not found. Skipping...
# Processing Record 5 of Set 2 | hofn
# Processing Record 6 of Set 2 | dawei
# Processing Record 7 of Set 2 | lazaro cardenas
# Processing Record 8 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 2 | watertown
# Processing Record 10 of Set 2 | verkhniy baskunchak
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | carnarvon
# Processing Record 13 of Set 2 | te anau
# Processing Record 14 of Set 2 | dunedin
# Processing Record 15 of Set 2 | bella vista
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | srednekolymsk
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | vila velha
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | iracoubo
# Processing Record 23 of Set 2 | albany
# Processing Record 24 of Set 2 | altamira
# Processing Record 25 of Set 2 | port hardy
# Processing Record 26 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 2 | leningradskiy
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | alice springs
# Processing Record 30 of Set 2 | provideniya
# Processing Record 31 of Set 2 | sampit
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | iqaluit
# Processing Record 35 of Set 2 | poum
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | yellowknife
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | hobart
# Processing Record 42 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 2 | dukat
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | opuwo
# Processing Record 46 of Set 2 | prince rupert
# Processing Record 47 of Set 2 | kavaratti
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | anbu
# Processing Record 50 of Set 2 | tongliao
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | karasjok
# Processing Record 3 of Set 3 | pemberton
# Processing Record 4 of Set 3 | saskylakh
# Processing Record 5 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | udachnyy
# Processing Record 8 of Set 3 | seydi
# Processing Record 9 of Set 3 | busselton
# Processing Record 10 of Set 3 | ahipara
# Processing Record 11 of Set 3 | yashan
# Processing Record 12 of Set 3 | victoria
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | virginia beach
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | lata
# Processing Record 17 of Set 3 | asosa
# Processing Record 18 of Set 3 | tucumcari
# Processing Record 19 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 3 | manado
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | vao
# Processing Record 24 of Set 3 | chalinze
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | billings
# Processing Record 27 of Set 3 | portland
# Processing Record 28 of Set 3 | kapaa
# Processing Record 29 of Set 3 | san cristobal
# Processing Record 30 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | fairbanks
# Processing Record 33 of Set 3 | lampang
# Processing Record 34 of Set 3 | kayes
# Processing Record 35 of Set 3 | uspenka
# Processing Record 36 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 3 | montrose
# Processing Record 38 of Set 3 | zhmerynka
# Processing Record 39 of Set 3 | lavrentiya
# Processing Record 40 of Set 3 | khatanga
# Processing Record 41 of Set 3 | ixtapa
# Processing Record 42 of Set 3 | saint-hyacinthe
# Processing Record 43 of Set 3 | puerto madryn
# Processing Record 44 of Set 3 | marang
# Processing Record 45 of Set 3 | saint-georges
# Processing Record 46 of Set 3 | kuva
# City not found. Skipping...
# Processing Record 47 of Set 3 | springbok
# Processing Record 48 of Set 3 | mount gambier
# Processing Record 49 of Set 3 | champerico
# Processing Record 50 of Set 3 | ponta delgada
# Processing Record 1 of Set 4 | lantawan
# Processing Record 2 of Set 4 | juneau
# Processing Record 3 of Set 4 | kolpashevo
# Processing Record 4 of Set 4 | rio grande
# Processing Record 5 of Set 4 | kashi
# Processing Record 6 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 4 | najran
# Processing Record 8 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 4 | robertsport
# Processing Record 10 of Set 4 | tiksi
# Processing Record 11 of Set 4 | port macquarie
# Processing Record 12 of Set 4 | ilinskiy
# Processing Record 13 of Set 4 | port hedland
# Processing Record 14 of Set 4 | marsh harbour
# Processing Record 15 of Set 4 | chokurdakh
# Processing Record 16 of Set 4 | kamenka
# Processing Record 17 of Set 4 | huadian
# Processing Record 18 of Set 4 | marietta
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | den helder
# Processing Record 21 of Set 4 | shimoda
# Processing Record 22 of Set 4 | aswan
# Processing Record 23 of Set 4 | noumea
# Processing Record 24 of Set 4 | pangnirtung
# Processing Record 25 of Set 4 | tezu
# Processing Record 26 of Set 4 | itarema
# Processing Record 27 of Set 4 | doha
# Processing Record 28 of Set 4 | san patricio
# Processing Record 29 of Set 4 | asau
# Processing Record 30 of Set 4 | tinyahuarco
# Processing Record 31 of Set 4 | tuatapere
# Processing Record 32 of Set 4 | hauterive
# Processing Record 33 of Set 4 | ust-ishim
# Processing Record 34 of Set 4 | bengkulu
# Processing Record 35 of Set 4 | pui
# Processing Record 36 of Set 4 | coihaique
# Processing Record 37 of Set 4 | linqiong
# Processing Record 38 of Set 4 | srivardhan
# Processing Record 39 of Set 4 | sosnovo-ozerskoye
# Processing Record 40 of Set 4 | taltal
# Processing Record 41 of Set 4 | kodinsk
# Processing Record 42 of Set 4 | sarh
# Processing Record 43 of Set 4 | yazman
# Processing Record 44 of Set 4 | opochka
# Processing Record 45 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 4 | farias brito
# Processing Record 47 of Set 4 | cornwall
# Processing Record 48 of Set 4 | sawasawa
# City not found. Skipping...
# Processing Record 49 of Set 4 | hare bay
# Processing Record 50 of Set 4 | san gabriel casa blanca
# Processing Record 1 of Set 5 | baijiantan
# Processing Record 2 of Set 5 | ribeira grande
# Processing Record 3 of Set 5 | urazovo
# Processing Record 4 of Set 5 | codrington
# Processing Record 5 of Set 5 | mahur
# Processing Record 6 of Set 5 | antofagasta
# Processing Record 7 of Set 5 | adrar
# Processing Record 8 of Set 5 | brae
# Processing Record 9 of Set 5 | ust-kan
# Processing Record 10 of Set 5 | khash
# Processing Record 11 of Set 5 | nantucket
# Processing Record 12 of Set 5 | makurdi
# Processing Record 13 of Set 5 | kazerun
# Processing Record 14 of Set 5 | gamba
# Processing Record 15 of Set 5 | ganzhou
# Processing Record 16 of Set 5 | tzucacab
# Processing Record 17 of Set 5 | nsanje
# Processing Record 18 of Set 5 | oriximina
# Processing Record 19 of Set 5 | alta gracia
# Processing Record 20 of Set 5 | kahului
# Processing Record 21 of Set 5 | hay river
# Processing Record 22 of Set 5 | liwale
# Processing Record 23 of Set 5 | senovo
# Processing Record 24 of Set 5 | tatawin
# Processing Record 25 of Set 5 | okhotsk
# Processing Record 26 of Set 5 | narva-joesuu
# Processing Record 27 of Set 5 | namibe
# Processing Record 28 of Set 5 | lorengau
# Processing Record 29 of Set 5 | pithiviers
# Processing Record 30 of Set 5 | lagoa
# Processing Record 31 of Set 5 | smiltene
# Processing Record 32 of Set 5 | arona
# Processing Record 33 of Set 5 | rio gallegos
# Processing Record 34 of Set 5 | peleduy
# Processing Record 35 of Set 5 | clyde river
# Processing Record 36 of Set 5 | charters towers
# Processing Record 37 of Set 5 | necochea
# Processing Record 38 of Set 5 | kuytun
# Processing Record 39 of Set 5 | bongandanga
# Processing Record 40 of Set 5 | inhambane
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | qaanaaq
# Processing Record 43 of Set 5 | broome
# Processing Record 44 of Set 5 | rosarito
# Processing Record 45 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 5 | thayetmyo
# Processing Record 47 of Set 5 | narsaq
# Processing Record 48 of Set 5 | capao da canoa
# Processing Record 49 of Set 5 | sandpoint
# Processing Record 50 of Set 5 | caracuaro
# Processing Record 1 of Set 6 | nome
# Processing Record 2 of Set 6 | kushima
# Processing Record 3 of Set 6 | luzhou
# Processing Record 4 of Set 6 | atar
# Processing Record 5 of Set 6 | avarua
# Processing Record 6 of Set 6 | oktyabrskoye
# Processing Record 7 of Set 6 | tessalit
# Processing Record 8 of Set 6 | japura
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 6 | atasu
# Processing Record 12 of Set 6 | tilichiki
# Processing Record 13 of Set 6 | chuy
# Processing Record 14 of Set 6 | krasnohrad
# Processing Record 15 of Set 6 | bambous virieux
# Processing Record 16 of Set 6 | arraial do cabo
# Processing Record 17 of Set 6 | wattegama
# Processing Record 18 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 6 | tias
# Processing Record 20 of Set 6 | bilibino
# Processing Record 21 of Set 6 | itupiranga
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | gzhatsk
# City not found. Skipping...
# Processing Record 24 of Set 6 | saint george
# Processing Record 25 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 26 of Set 6 | steamboat springs
# Processing Record 27 of Set 6 | kavieng
# Processing Record 28 of Set 6 | morros
# Processing Record 29 of Set 6 | pisco
# Processing Record 30 of Set 6 | sorong
# Processing Record 31 of Set 6 | griffith
# Processing Record 32 of Set 6 | byron bay
# Processing Record 33 of Set 6 | yar-sale
# Processing Record 34 of Set 6 | diego de almagro
# Processing Record 35 of Set 6 | esperance
# Processing Record 36 of Set 6 | ginda
# Processing Record 37 of Set 6 | los llanos de aridane
# Processing Record 38 of Set 6 | toma
# Processing Record 39 of Set 6 | ribas do rio pardo
# Processing Record 40 of Set 6 | jaguaruna
# Processing Record 41 of Set 6 | abha
# Processing Record 42 of Set 6 | sao joao da barra
# Processing Record 43 of Set 6 | jomalig
# City not found. Skipping...
# Processing Record 44 of Set 6 | poronaysk
# Processing Record 45 of Set 6 | half moon bay
# Processing Record 46 of Set 6 | cidreira
# Processing Record 47 of Set 6 | pochutla
# Processing Record 48 of Set 6 | ninotsminda
# Processing Record 49 of Set 6 | college
# Processing Record 50 of Set 6 | sorland
# Processing Record 1 of Set 7 | villa rica
# Processing Record 2 of Set 7 | svetlyy
# Processing Record 3 of Set 7 | kendari
# Processing Record 4 of Set 7 | faya
# Processing Record 5 of Set 7 | sur
# Processing Record 6 of Set 7 | mednogorsk
# Processing Record 7 of Set 7 | bathsheba
# Processing Record 8 of Set 7 | aklavik
# Processing Record 9 of Set 7 | baruun-urt
# Processing Record 10 of Set 7 | pa daet
# Processing Record 11 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 7 | kununurra
# Processing Record 13 of Set 7 | macau
# Processing Record 14 of Set 7 | ketchikan
# Processing Record 15 of Set 7 | zhigansk
# Processing Record 16 of Set 7 | bosobolo
# Processing Record 17 of Set 7 | faanui
# Processing Record 18 of Set 7 | general salgado
# Processing Record 19 of Set 7 | cabedelo
# Processing Record 20 of Set 7 | tynda
# Processing Record 21 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 7 | gap
# Processing Record 23 of Set 7 | mecca
# Processing Record 24 of Set 7 | egvekinot
# Processing Record 25 of Set 7 | yulara
# Processing Record 26 of Set 7 | plettenberg bay
# Processing Record 27 of Set 7 | nicoya
# Processing Record 28 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 7 | mirabad
# Processing Record 30 of Set 7 | tura
# Processing Record 31 of Set 7 | kungurtug
# Processing Record 32 of Set 7 | bani
# Processing Record 33 of Set 7 | bandarbeyla
# Processing Record 34 of Set 7 | katsuura
# Processing Record 35 of Set 7 | edremit
# Processing Record 36 of Set 7 | englewood
# Processing Record 37 of Set 7 | anadyr
# Processing Record 38 of Set 7 | constitucion
# Processing Record 39 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 7 | gurgentepe
# Processing Record 41 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 7 | camana
# Processing Record 43 of Set 7 | guerrero negro
# Processing Record 44 of Set 7 | the valley
# Processing Record 45 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 7 | davidson
# Processing Record 47 of Set 7 | batagay
# Processing Record 48 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 7 | tigre
# Processing Record 50 of Set 7 | kurumkan
# Processing Record 1 of Set 8 | hassleholm
# Processing Record 2 of Set 8 | hualmay
# Processing Record 3 of Set 8 | ratnagiri
# Processing Record 4 of Set 8 | mandalgovi
# Processing Record 5 of Set 8 | iguguno
# Processing Record 6 of Set 8 | abis
# Processing Record 7 of Set 8 | biak
# Processing Record 8 of Set 8 | gorontalo
# Processing Record 9 of Set 8 | uporovo
# Processing Record 10 of Set 8 | benghazi
# Processing Record 11 of Set 8 | bafq
# Processing Record 12 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 8 | plaster rock
# Processing Record 14 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 15 of Set 8 | soe
# Processing Record 16 of Set 8 | husavik
# Processing Record 17 of Set 8 | beyneu
# Processing Record 18 of Set 8 | khed brahma
# Processing Record 19 of Set 8 | chifeng
# Processing Record 20 of Set 8 | shingu
# Processing Record 21 of Set 8 | sidi ali
# Processing Record 22 of Set 8 | ola
# Processing Record 23 of Set 8 | petrovsk
# Processing Record 24 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 8 | dingle
# Processing Record 26 of Set 8 | pout
# Processing Record 27 of Set 8 | lac du bonnet
# Processing Record 28 of Set 8 | mandan
# Processing Record 29 of Set 8 | richards bay
# Processing Record 30 of Set 8 | hengshui
# Processing Record 31 of Set 8 | ostrovnoy
# Processing Record 32 of Set 8 | qui nhon
# Processing Record 33 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | vestmanna
# Processing Record 35 of Set 8 | odessa
# Processing Record 36 of Set 8 | fort nelson
# Processing Record 37 of Set 8 | fukue
# Processing Record 38 of Set 8 | gat
# Processing Record 39 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 8 | yerbogachen
# Processing Record 41 of Set 8 | hobyo
# Processing Record 42 of Set 8 | boguchany
# Processing Record 43 of Set 8 | sokode
# Processing Record 44 of Set 8 | luwuk
# Processing Record 45 of Set 8 | saint-augustin
# Processing Record 46 of Set 8 | uyuni
# Processing Record 47 of Set 8 | kruisfontein
# Processing Record 48 of Set 8 | waddan
# Processing Record 49 of Set 8 | kalabo
# Processing Record 50 of Set 8 | chapleau
# Processing Record 1 of Set 9 | petrovac
# Processing Record 2 of Set 9 | smestad
# Processing Record 3 of Set 9 | saint anthony
# Processing Record 4 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 9 | lasa
# Processing Record 6 of Set 9 | mount isa
# Processing Record 7 of Set 9 | sibu
# Processing Record 8 of Set 9 | tocopilla
# Processing Record 9 of Set 9 | mareeba
# Processing Record 10 of Set 9 | nabire
# Processing Record 11 of Set 9 | naugarzan
# City not found. Skipping...
# Processing Record 12 of Set 9 | tokzar
# City not found. Skipping...
# Processing Record 13 of Set 9 | creel
# Processing Record 14 of Set 9 | kattivakkam
# Processing Record 15 of Set 9 | ban dung
# Processing Record 16 of Set 9 | aksu
# Processing Record 17 of Set 9 | hovd
# Processing Record 18 of Set 9 | hambantota
# Processing Record 19 of Set 9 | huai thalaeng
# Processing Record 20 of Set 9 | kalmunai
# Processing Record 21 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 9 | praia da vitoria
# Processing Record 23 of Set 9 | warrnambool
# Processing Record 24 of Set 9 | baykit
# Processing Record 25 of Set 9 | bahia honda
# Processing Record 26 of Set 9 | khor
# Processing Record 27 of Set 9 | boyolangu
# Processing Record 28 of Set 9 | saldanha
# Processing Record 29 of Set 9 | querfurt
# Processing Record 30 of Set 9 | morondava
# Processing Record 31 of Set 9 | beringovskiy
# Processing Record 32 of Set 9 | halifax
# Processing Record 33 of Set 9 | christchurch
# Processing Record 34 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 9 | agadez
# Processing Record 36 of Set 9 | hami
# Processing Record 37 of Set 9 | lapua
# Processing Record 38 of Set 9 | cap malheureux
# Processing Record 39 of Set 9 | harper
# Processing Record 40 of Set 9 | shelburne
# Processing Record 41 of Set 9 | ancud
# Processing Record 42 of Set 9 | sunyani
# Processing Record 43 of Set 9 | ilulissat
# Processing Record 44 of Set 9 | santa rosa
# Processing Record 45 of Set 9 | rupert
# Processing Record 46 of Set 9 | bagepalli
# Processing Record 47 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 9 | beidao
# Processing Record 49 of Set 9 | asfi
# Processing Record 50 of Set 9 | kisangani
# Processing Record 1 of Set 10 | san isidro
# Processing Record 2 of Set 10 | abashiri
# Processing Record 3 of Set 10 | liverpool
# Processing Record 4 of Set 10 | yatou
# Processing Record 5 of Set 10 | honningsvag
# Processing Record 6 of Set 10 | vermilion
# Processing Record 7 of Set 10 | katobu
# Processing Record 8 of Set 10 | nemuro
# Processing Record 9 of Set 10 | khandyga
# Processing Record 10 of Set 10 | talnakh
# Processing Record 11 of Set 10 | cefalu
# Processing Record 12 of Set 10 | taoudenni
# Processing Record 13 of Set 10 | montego bay
# Processing Record 14 of Set 10 | namatanai
# Processing Record 15 of Set 10 | klaksvik
# Processing Record 16 of Set 10 | kouroussa
# Processing Record 17 of Set 10 | areosa
# Processing Record 18 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 10 | smoljan
# Processing Record 20 of Set 10 | taga
# Processing Record 21 of Set 10 | ayr
# Processing Record 22 of Set 10 | vila
# Processing Record 23 of Set 10 | axim
# Processing Record 24 of Set 10 | ayagoz
# Processing Record 25 of Set 10 | vila franca do campo
# Processing Record 26 of Set 10 | jaciara
# Processing Record 27 of Set 10 | moratuwa
# Processing Record 28 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 10 | ambilobe
# Processing Record 30 of Set 10 | pasni
# Processing Record 31 of Set 10 | zapadnaya dvina
# Processing Record 32 of Set 10 | nizhnyaya omka
# Processing Record 33 of Set 10 | enna
# Processing Record 34 of Set 10 | korla
# Processing Record 35 of Set 10 | turan
# Processing Record 36 of Set 10 | sept-iles
# Processing Record 37 of Set 10 | nueva guinea
# Processing Record 38 of Set 10 | coolum beach
# Processing Record 39 of Set 10 | tommot
# Processing Record 40 of Set 10 | salalah
# Processing Record 41 of Set 10 | kysyl-syr
# Processing Record 42 of Set 10 | dutse
# Processing Record 43 of Set 10 | ngaoundere
# Processing Record 44 of Set 10 | lebanon
# Processing Record 45 of Set 10 | nizhniy ingash
# Processing Record 46 of Set 10 | cherskiy
# Processing Record 47 of Set 10 | diffa
# Processing Record 48 of Set 10 | chenghai
# Processing Record 49 of Set 10 | sovetskiy
# Processing Record 50 of Set 10 | turayf
# Processing Record 1 of Set 11 | north platte
# Processing Record 2 of Set 11 | kalemie
# Processing Record 3 of Set 11 | colares
# Processing Record 4 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 11 | samarai
# Processing Record 6 of Set 11 | vostok
# Processing Record 7 of Set 11 | yagodnoye
# Processing Record 8 of Set 11 | artesia
# Processing Record 9 of Set 11 | kalengwa
# Processing Record 10 of Set 11 | cayenne
# Processing Record 11 of Set 11 | itum-kale
# Processing Record 12 of Set 11 | kuna
# Processing Record 13 of Set 11 | ico
# Processing Record 14 of Set 11 | komatipoort
# Processing Record 15 of Set 11 | calvinia
# Processing Record 16 of Set 11 | paamiut
# Processing Record 17 of Set 11 | vilhena
# Processing Record 18 of Set 11 | okha
# Processing Record 19 of Set 11 | camacha
# Processing Record 20 of Set 11 | wodonga
# Processing Record 21 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 22 of Set 11 | tambopata
# Processing Record 23 of Set 11 | oudtshoorn
# Processing Record 24 of Set 11 | coquimbo
# Processing Record 25 of Set 11 | concepcion
# Processing Record 26 of Set 11 | verkhnyaya inta
# Processing Record 27 of Set 11 | wilmington
# Processing Record 28 of Set 11 | pilibhit
# Processing Record 29 of Set 11 | parana
# Processing Record 30 of Set 11 | magog
# Processing Record 31 of Set 11 | bouar
# Processing Record 32 of Set 11 | nalut
# Processing Record 33 of Set 11 | stepnogorsk
# Processing Record 34 of Set 11 | ossora
# Processing Record 35 of Set 11 | roald
# Processing Record 36 of Set 11 | kaitangata
# Processing Record 37 of Set 11 | abu samrah
# Processing Record 38 of Set 11 | quesnel
# Processing Record 39 of Set 11 | yumen
# Processing Record 40 of Set 11 | kharan
# Processing Record 41 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 42 of Set 11 | srandakan
# Processing Record 43 of Set 11 | jinchang
# Processing Record 44 of Set 11 | labuhan
# Processing Record 45 of Set 11 | touros
# Processing Record 46 of Set 11 | moussoro
# Processing Record 47 of Set 11 | rawson
# Processing Record 48 of Set 11 | ironton
# Processing Record 49 of Set 11 | kaihua
# Processing Record 50 of Set 11 | vaasa
# Processing Record 1 of Set 12 | zhangjiakou
# Processing Record 2 of Set 12 | sumkino
# Processing Record 3 of Set 12 | sahuaripa
# Processing Record 4 of Set 12 | fort-shevchenko
# Processing Record 5 of Set 12 | fortuna
# Processing Record 6 of Set 12 | dawlatabad
# Processing Record 7 of Set 12 | meulaboh
# Processing Record 8 of Set 12 | nola
# Processing Record 9 of Set 12 | palmares do sul
# Processing Record 10 of Set 12 | banda aceh
# Processing Record 11 of Set 12 | san quintin
# Processing Record 12 of Set 12 | nemetker
# Processing Record 13 of Set 12 | berlevag
# Processing Record 14 of Set 12 | chunskiy
# Processing Record 15 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 12 | muros
# Processing Record 17 of Set 12 | gbadolite
# Processing Record 18 of Set 12 | saint-pierre
# Processing Record 19 of Set 12 | aleksandrov gay
# Processing Record 20 of Set 12 | moron
# Processing Record 21 of Set 12 | karymskoye
# Processing Record 22 of Set 12 | goderich
# Processing Record 23 of Set 12 | puebloviejo
# Processing Record 24 of Set 12 | mookane
# Processing Record 25 of Set 12 | moanda
# Processing Record 26 of Set 12 | nogent-le-rotrou
# Processing Record 27 of Set 12 | kieta
# Processing Record 28 of Set 12 | comodoro rivadavia
# Processing Record 29 of Set 12 | alugan
# Processing Record 30 of Set 12 | orgun
# City not found. Skipping...
# Processing Record 31 of Set 12 | lake havasu city
# Processing Record 32 of Set 12 | jiwani
# Processing Record 33 of Set 12 | leshukonskoye
# Processing Record 34 of Set 12 | gombong
# Processing Record 35 of Set 12 | santa cruz
# Processing Record 36 of Set 12 | togitsu
# Processing Record 37 of Set 12 | batagay-alyta
# Processing Record 38 of Set 12 | ranong
# Processing Record 39 of Set 12 | tautira
# Processing Record 40 of Set 12 | pimentel
# Processing Record 41 of Set 12 | ahome
# Processing Record 42 of Set 12 | vizinga
# Processing Record 43 of Set 12 | akhtubinsk
# Processing Record 44 of Set 12 | cabo san lucas
# Processing Record 45 of Set 12 | ukiah
# Processing Record 46 of Set 12 | hasaki
# Processing Record 47 of Set 12 | saint-joseph
# Processing Record 48 of Set 12 | harnosand
# Processing Record 49 of Set 12 | sidhauli
# Processing Record 50 of Set 12 | nahariyya
# Processing Record 1 of Set 13 | xining
# Processing Record 2 of Set 13 | havre
# Processing Record 3 of Set 13 | puerto leguizamo
# Processing Record 4 of Set 13 | ilka
# City not found. Skipping...
# Processing Record 5 of Set 13 | ahvaz
# Processing Record 6 of Set 13 | canutama
# Processing Record 7 of Set 13 | clarence town
# Processing Record 8 of Set 13 | ginir
# Processing Record 9 of Set 13 | teya
# Processing Record 10 of Set 13 | yamada
# Processing Record 11 of Set 13 | chalus
# Processing Record 12 of Set 13 | sola
# Processing Record 13 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 13 | igrim
# Processing Record 15 of Set 13 | golyshmanovo
# Processing Record 16 of Set 13 | camaguey
# Processing Record 17 of Set 13 | ulladulla
# Processing Record 18 of Set 13 | kholodnyy
# Processing Record 19 of Set 13 | marquette
# Processing Record 20 of Set 13 | shiloh
# Processing Record 21 of Set 13 | cozumel
# Processing Record 22 of Set 13 | willowmore
# Processing Record 23 of Set 13 | luganville
# Processing Record 24 of Set 13 | nelson bay
# Processing Record 25 of Set 13 | damascus
# Processing Record 26 of Set 13 | oranjemund
# Processing Record 27 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 13 | kanniyakumari
# Processing Record 29 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 13 | nongstoin
# Processing Record 31 of Set 13 | melipilla
# Processing Record 32 of Set 13 | eureka
# Processing Record 33 of Set 13 | ponnampet
# Processing Record 34 of Set 13 | kot samaba
# Processing Record 35 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 36 of Set 13 | pedasi
# Processing Record 37 of Set 13 | bambanglipuro
# Processing Record 38 of Set 13 | havoysund
# Processing Record 39 of Set 13 | isangel
# Processing Record 40 of Set 13 | hamilton
# Processing Record 41 of Set 13 | deer lake
# Processing Record 42 of Set 13 | methoni
# Processing Record 43 of Set 13 | terenos
# Processing Record 44 of Set 13 | namtsy
# Processing Record 45 of Set 13 | san policarpo
# Processing Record 46 of Set 13 | prokudskoye
# Processing Record 47 of Set 13 | ashford
# Processing Record 48 of Set 13 | nyurba
# Processing Record 49 of Set 13 | peniche
# Processing Record 50 of Set 13 | ongandjera
# Processing Record 1 of Set 14 | dehloran
# Processing Record 2 of Set 14 | uong bi
# Processing Record 3 of Set 14 | padang
# Processing Record 4 of Set 14 | ankang
# Processing Record 5 of Set 14 | mitu
# Processing Record 6 of Set 14 | nagapattinam
# Processing Record 7 of Set 14 | nanhai
# Processing Record 8 of Set 14 | avera
# Processing Record 9 of Set 14 | juegang
# Processing Record 10 of Set 14 | iberia
# Processing Record 11 of Set 14 | maues
# Processing Record 12 of Set 14 | manzhouli
# Processing Record 13 of Set 14 | dapaong
# Processing Record 14 of Set 14 | chacabuco
# Processing Record 15 of Set 14 | saint-francois
# Processing Record 16 of Set 14 | porto walter
# Processing Record 17 of Set 14 | hayato
# City not found. Skipping...
# Processing Record 18 of Set 14 | lumeje
# Processing Record 19 of Set 14 | nichinan
# Processing Record 20 of Set 14 | sal rei
# Processing Record 21 of Set 14 | beloha
# Processing Record 22 of Set 14 | asadabad
# Processing Record 23 of Set 14 | tambun
# Processing Record 24 of Set 14 | gumdag
# Processing Record 25 of Set 14 | zastron
# Processing Record 26 of Set 14 | ahuimanu
# Processing Record 27 of Set 14 | stromness
# Processing Record 28 of Set 14 | silyanah
# City not found. Skipping...
# Processing Record 29 of Set 14 | doka
# Processing Record 30 of Set 14 | mao
# Processing Record 31 of Set 14 | ambon
# Processing Record 32 of Set 14 | port-cartier
# Processing Record 33 of Set 14 | yermolayevo
# Processing Record 34 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 35 of Set 14 | pemangkat
# Processing Record 36 of Set 14 | erenhot
# Processing Record 37 of Set 14 | jalpan
# Processing Record 38 of Set 14 | abaza
# Processing Record 39 of Set 14 | borama
# City not found. Skipping...
# Processing Record 40 of Set 14 | grenada
# Processing Record 41 of Set 14 | la grande
# Processing Record 42 of Set 14 | mankono
# Processing Record 43 of Set 14 | sao filipe
# Processing Record 44 of Set 14 | novyy urgal
# Processing Record 45 of Set 14 | sigulda
# Processing Record 46 of Set 14 | acapulco
# Processing Record 47 of Set 14 | samfya
# Processing Record 48 of Set 14 | kenai
# Processing Record 49 of Set 14 | zakopane
# Processing Record 50 of Set 14 | vanderhoof
# Processing Record 1 of Set 15 | xuanhua
# Processing Record 2 of Set 15 | bayir
# Processing Record 3 of Set 15 | emerald
# Processing Record 4 of Set 15 | envira
# Processing Record 5 of Set 15 | port keats
# Processing Record 6 of Set 15 | gainesville
# Processing Record 7 of Set 15 | sawtell
# Processing Record 8 of Set 15 | mutare
# Processing Record 9 of Set 15 | sabzevar
# Processing Record 10 of Set 15 | santa ana
# Processing Record 11 of Set 15 | acatlan
# Processing Record 12 of Set 15 | myski
# Processing Record 13 of Set 15 | tual
# Processing Record 14 of Set 15 | ugoofaaru
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 657

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    grand gaube -20.0064   57.6608     73.80        74           8
# 1          bluff -46.6000  168.3333     55.22        73          18
# 2      princeton  25.5384  -80.4089     81.01        88           1
# 3         trairi  -3.2778  -39.2689     77.58        78           3
# 4     butaritari   3.0707  172.7902     83.19        74          91
# ..           ...      ...       ...       ...       ...         ...
# 652    santa ana  33.7456 -117.8678     84.79        74          20
# 653      acatlan  20.1500  -98.4500     57.72        93          98
# 654        myski  53.7090   87.8014     65.30        92         100
# 655         tual  -5.6667  132.7500     81.86        76          48
# 656    ugoofaaru   5.6667   73.0000     82.78        70         100
#
#      Wind Speed Current Description Country
# 0         21.68          light rain      MU
# 1         13.06          few clouds      NZ
# 2          5.75           clear sky      US
# 3          9.75           clear sky      BR
# 4          7.90     overcast clouds      KI
# ..          ...                 ...     ...
# 652        1.99          few clouds      US
# 653        2.35     overcast clouds      MX
# 654        3.49          light rain      RU
# 655       18.52    scattered clouds      ID
# 656       17.60     overcast clouds      MV
#
# [657 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
